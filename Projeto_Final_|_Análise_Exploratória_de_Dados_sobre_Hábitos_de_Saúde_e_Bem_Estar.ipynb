# %% [markdown]
# <a href="https://colab.research.google.com/github/jaozin011/aaaaaaaaa-tabela2/blob/main/Projeto_Final_%7C_An%C3%A1lise_Explorat%C3%B3ria_de_Dados_sobre_H%C3%A1bitos_de_Sa%C3%BAde_e_Bem_Estar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Análise Exploratória de Dados sobre impacto de jogos na vida das pessoas
#
# **Objetivo do Projeto**
#
# O objetivo é realizar uma análise exploratória de dados sobre influência de jogos na vida das pessoas

# %% [markdown]
# **PESQUISA SOBRE JOGOS**
#
# Somos uma equipe de desenvolvimento de games e estamos realizando uma pesquisa para entender melhor os hábitos e preferências dos jogadores. Sua opinião é extremamente valiosa para nós e levará apenas 5 a 7 minutos para ser respondida. Todas as informações fornecidas são anônimas e confidenciais, sendo usadas apenas para fins de pesquisa.

# %%
import pandas as pd
dados = pd.read_csv("https://docs.google.com/spreadsheets/d/e/2PACX-1vTEEre1CHDcors3KOWsWBxJY3W7JGCe6wTxBviAi5zdjB7KchBlKouMiYLXnuJQrvbusvif_t0oOLca/pub?output=csv")

# %%
dados
# Out:
#    Carimbo de data/hora Qual é o seu gênero  Qual a sua idade?  \
# 0   04/11/2024 12:50:16            feminino                 12
# 1   04/11/2024 12:51:53           masculino                 18
# 2   04/11/2024 12:52:19            feminino                 25
# 3   04/11/2024 12:52:36            feminino                 31
# 4   04/11/2024 12:53:03            feminino                 21
# 5   04/11/2024 12:53:18            feminino                 12
# 6   04/11/2024 13:36:14            feminino                  8
# 7   04/11/2024 13:36:38            feminino                 51
# 8   04/11/2024 13:37:02            feminino                 21
# 9   04/11/2024 13:37:30            feminino                 18
# 10  04/11/2024 13:37:34           masculino                 16
# 11  04/11/2024 13:38:05           masculino                 17
# 12  04/11/2024 13:38:15           masculino                 11
# 13  04/11/2024 13:38:25           masculino                 21
# ...

# %%
dados.hist()
# Out:
# array([[<Axes: title={'center': 'Qual a sua idade?'}>,
#         <Axes: title={'center': 'Quantas frutas você se alimenta quando joga'}>],
#        [<Axes: title={'center': 'Quanto horas você costuma jogar?'}>,
#         <Axes: >]], dtype=object)

# %%
dados["Quantos dias por semana você pratica atividades físicas?"].hist()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Quantos dias por semana você pratica atividades físicas?'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-517534785.py in <cell line: 0>()
# ...

# %%
dados["Quantas porções de frutas você consome em uma semana?"].hist()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Quantas porções de frutas você consome em uma semana?'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-3733635616.py in <cell line: 0>()
# ...

# %% [markdown]
# ### Resumo do histograma
#
# * A maioria dos participantes pratica atividade física entre 0 e 1 vez por semana. Isso pode ser visto pela alta frequência de respostas próximas a esses valores.
# * Poucos participantes praticam atividade física de maneira mais intensa (de 4 a 7 vezes por semana), sugerindo que uma prática regular de exercícios ainda não é comum entre os respondentes.
# * Essa distribuição é muito concentrada em valores baixos, o que pode indicar uma tendência de baixa frequência de atividade física na amostra.

# %% [markdown]
# ### Resumo
#
# **Consumo Baixo de Jogos**: A quantidade mais comum de tempo gasto jogando entre os participantes é de 1 a 5 horas por semana, com 12 pessoas relatando essa faixa de horas. Isso indica que, para a maioria, o tempo dedicado a jogos é moderado e limitado.
#
# **Ausência de Consumo**: Existem 4 participantes que relataram não jogar nenhuma hora por semana (valor de 0). Esse dado reforça a tendência de consumo baixo ou nulo de jogos para uma parte da amostra.
#
# **Outliers de Consumo Alto**: Há alguns valores atípicos significativos, como um participante jogando 40 horas por semana e outro consumindo 25 horas por semana. Esses valores estão bem acima da média e podem indicar jogadores mais dedicados, possivelmente envolvidos em competições ou com mais tempo livre.

# %%
dados.describe()
# Out:
#        Quantos dias por semana você pratica atividades físicas?  \
# count                                          23.000000
# mean                                            1.608696
# std                                             1.876630
# min                                             0.000000
# 25%                                             0.500000
# 50%                                             1.000000
# 75%                                             2.000000
# max                                             7.000000
#
#        Quantas porções de frutas você consome em uma semana?  \
# count                                          23.000000
# mean                                            4.478261
# std                                             9.004391
# min                                             0.000000
# 25%                                             1.000000
# 50%                                             2.000000
# ...

# %% [markdown]
# ### Destaques
#
# * **Count:** Indica o número total de respostas válidas para cada pergunta (neste caso, 23 para cada coluna).
# * **Mean (Média):** Representa a média aritmética dos valores para cada coluna. No caso de "Quantas porções de frutas você consome em uma semana?", a média é de aproximadamente 4,48 porções, o que sugere um consumo moderado. Já a média de 10,39 para bebidas açucaradas indica um consumo elevado em comparação com frutas.
# * **Std (Desvio Padrão):** Mede a variabilidade dos dados. Um valor alto de desvio padrão, como 12,61 para bebidas açucaradas e 14,04 para horas de dispositivos móveis, indica que há uma grande variação nas respostas entre os participantes.
# * **Min e Max:** Mostram os valores mínimo e máximo para cada coluna. Por exemplo, o consumo de frutas varia de 0 até 40 porções por semana, enquanto o tempo em dispositivos móveis vai de 2 a 50 horas semanais.

# %%
media_sono = dados["Quantas horas de sono você costuma ter em uma noite durante a semana?"].mean()
mediana_sono = dados["Quantas horas de sono você costuma ter em uma noite durante a semana?"].median()

print(media_sono)
print(mediana_sono)
# Out:
# 6.0
# 5.0

# %%
media_bebidas = dados["Quantas bebidas açucaradas (refrigerantes, sucos de caixinha ou energéticos) você consome em uma semana?"].mean()
mediana_bebidas = dados["Quantas bebidas açucaradas (refrigerantes, sucos de caixinha ou energéticos) você consome em uma semana?"].median()

print(media_bebidas)
print(mediana_bebidas)
# Out:
# 10.391304347826088
# 5.0

# %% [markdown]
# ### Principais informações
#
# **Horas de Sono por Noite**
# * Média: A média de horas de sono entre os participantes é de 6 horas por noite.
# * Mediana: A mediana é de 5 horas por noite, o que significa que metade dos participantes dorme até 5 horas ou menos, enquanto a outra metade dorme mais que isso.
#
# **Consumo de Bebidas Açucaradas por Semana**
# * Média: O consumo médio de bebidas açucaradas é de aproximadamente 10,39 bebidas por semana.
# * Mediana: A mediana é de 5 bebidas por semana, indicando que metade dos participantes consome até 5 bebidas açucaradas por semana, enquanto a outra metade consome mais.
